# %% [markdown]
# ## Loading the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
# Importing statsmodels modules 
import statsmodels.formula.api as smf
import statsmodels.tsa.api as smt
import statsmodels.api as sm
import scipy.stats as scs
import pandas as pd

# %% [markdown]
# ### Tsplot function

# %%
def tsplot(y, lags=None, figsize=(10, 8), style='seaborn-deep'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        #mpl.rcParams['font.family'] = 'Ubuntu Mono'
        layout = (3, 2)
        ts_ax = plt.subplot2grid(layout, (0, 0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1, 0))
        pacf_ax = plt.subplot2grid(layout, (1, 1))
        qq_ax = plt.subplot2grid(layout, (2, 0))
        pp_ax = plt.subplot2grid(layout, (2, 1))
        
        y.plot(ax=ts_ax)
        ts_ax.set_title('Time Series Analysis Plots')
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.5)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.5)
        sm.qqplot(y, line='s', ax=qq_ax)
        qq_ax.set_title('QQ Plot')        
        scs.probplot(y, sparams=(y.mean(), y.std()), plot=pp_ax)

        plt.tight_layout()
    return 
def autocorrelation_plot(y, lags=None, figsize=(15, 5), style='seaborn-deep'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (1, 2)
        acf_ax = plt.subplot2grid(layout, (0, 0))
        pacf_ax = plt.subplot2grid(layout, (0, 1))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax, alpha=0.5)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax, alpha=0.5)
        plt.tight_layout()
    return
def thoretical_sample_plot(y, lags=None, figsize=(15, 5), style='seaborn-deep'):
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
    with plt.style.context(style):    
        fig = plt.figure(figsize=figsize)
        layout = (1, 2)
        pl1_ax = plt.subplot2grid(layout, (0, 0))
        pl2_ax = plt.subplot2grid(layout, (0, 1))
        sm.qqplot(y, line='s', ax=pl1_ax)
        pl1_ax.set_title('QQ Plot')        
        scs.probplot(y, sparams=(y.mean(), y.std()), plot=pl2_ax)
        plt.tight_layout()
    return

# %% [markdown]
# ## Question 1

# %%
np.random.seed(1) 
n_samples = int(1000)
white_noise = np.random.normal(size = n_samples)
plt.figure(figsize=(15, 5))
plt.plot(white_noise,color= '#16354d',marker = '.')
plt.title('White Noise',fontsize = 20)
plt.xlabel('Observation',fontsize = 15) #xlabel
plt.ylabel('Noise', fontsize = 15)#ylabel
plt.style.context('seaborn-deep')
mean, std = white_noise.mean(), white_noise.std()
print(f'mean = {np.round(mean,3)} and std = {np.round(std,3)}')
# Out:
# mean = 0.039 and std = 0.981

# %% [markdown]
# $y_t = 150+0.5* y_(t-1) + white_noise$

# %%
np.random.seed(1)
delta = 150    
phi_1 = -0.5
series  = np.random.normal(size = n_samples)
for t in range(n_samples):
    series[t] = delta+ phi_1*series[t-1] + white_noise[t]

# plotting thretical 
_1 = tsplot(series, lags =30)

# %%
# Finding the mean of auto regressive process of order 1 
mean = delta/ (1-phi_1)
print("mean = ", mean)
# Out:
# mean =  100.0

# %%
def predict(previous_observation):
    return 150-(0.5*(previous_observation)) + np.random.normal()

# %%
predict(85)  # above mean
# Out:
# 107.3467638382329

# %% [markdown]
# ## Question 2

# %%
np.random.seed(1) 
n_samples = int(50) # 
delta = 25 
phi_1 = 0.75

# defining the white noise 
white_noise = np.random.normal(size = n_samples)
plt.figure(figsize=(15, 5))
plt.plot(white_noise,color= '#16354d',marker = '.')
plt.title('White Noise',fontsize = 20)
plt.xlabel('Observation',fontsize = 15) #xlabel
plt.ylabel('Noise', fontsize = 15)#ylabel
plt.style.context('seaborn-deep')

mean_process = delta/(1-phi_1)


np.random.seed(1)
n_samples = int(50)   # 50 realizations 
a = 0.75
x = np.random.normal(size=n_samples)
 
for t in range(n_samples):
    x[t] = a*x[t-1] + white_noise[t] + 25 
    
_ = autocorrelation_plot(x, lags=24)

_ = thoretical_sample_plot(x, lags=24)

# %%
np.random.seed(1) 
n_samples = int(200) # 
delta = 25 
phi_1 = 0.75

# defining the white noise 
white_noise = np.random.normal(size = n_samples)
plt.figure(figsize=(15, 5))
plt.plot(white_noise,color= '#16354d',marker = '.')
plt.title('White Noise',fontsize = 20)
plt.xlabel('Observation',fontsize = 15) #xlabel
plt.ylabel('Noise', fontsize = 15)#ylabel
plt.style.context('seaborn-deep')
mean, std = white_noise.mean(), white_noise.std()

print(f'mean white noise = {np.round(mean,3)} and std = {np.round(std,3)}')


mean_process = delta/(1-phi_1)
print('mean of the process = ', mean_process)


np.random.seed(1)
a = 0.75
x = np.random.normal(size=n_samples)
 
for t in range(n_samples):
    x[t] = a*x[t-1] + white_noise[t] + 25 
    
_ = autocorrelation_plot(x, lags=30)



a = 0.75
x = w = np.random.normal(size=n_samples)
for t in range(n_samples):
    x[t] = a*x[t-1] + w[t] + 25 
    
_ = thoretical_sample_plot(x, lags=30)
# Out:
# mean white noise = 0.107 and std = 0.91
# mean of the process =  100.0

# %% [markdown]
# ## Question 3

# %%
n_samples = 10000  # will get a nice estimate of theoretical distribution 
np.random.seed(2)
white_noise = np.random.normal(size = n_samples, scale = 2)

x = np.random.normal(size=n_samples)
 
for t in range(n_samples):
    x[t] = white_noise[t-1] + white_noise[t] + 40

_ = autocorrelation_plot(x,lags = 30)

# %%
n_samples = 50
np.random.seed(2)
white_noise = np.random.normal(size = n_samples, scale = 2)

x = np.random.normal(size=n_samples)
 
for t in range(n_samples):
    x[t] = white_noise[t-1] + white_noise[t] + 40

_ = tsplot(x,lags = 20)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1434: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
n_samples = 200
np.random.seed(2)
white_noise = np.random.normal(size = n_samples, scale = 2)

x = np.random.normal(size=n_samples)
 
for t in range(n_samples):
    x[t] = white_noise[t-1] + white_noise[t] + 40

_ = tsplot(x,lags = 20)
