# %%
import os 
import pandas as pd

# %%
import warnings 
warnings.filterwarnings('ignore')
from matplotlib import pyplot as plt 
from statsmodels.tsa.api import ExponentialSmoothing,SimpleExpSmoothing,Holt
from pylab import rcParams
rcParams['figure.figsize'] = 20,5

# %%
df = pd.read_csv('Electric_Production.csv',index_col = 0)

# %%
df.shape
# Out:
# (397, 1)

# %%
df.head()
# Out:
#           IPG2211A2N
# DATE
# 1/1/1985     72.5052
# 2/1/1985     70.6720
# 3/1/1985     62.4502
# 4/1/1985     57.4714
# 5/1/1985     55.3151

# %%
import datetime
# df.index = [datetime.datetime.strptime(df.index[i],'%d/%m/%Y') for i in range(len(df))]

# %%
plt.plot(df['IPG2211A2N'][:50])
plt.xticks(rotation=45) 
plt.show()
